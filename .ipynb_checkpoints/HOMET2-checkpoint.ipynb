# %%
import numpy as np
#Создайте двумерный массив 10x3, заполненный случайными значениями. 
#В каждой строке выберите значение, наиболее близкое к 0.5.
(abs(np.random.random((10,3))-0.5)).min(axis=1)+0.5
# Out:
# array([0.70116971, 0.62934343, 0.52553024, 0.54507435, 0.70750042,
#        0.55451497, 0.53523591, 0.70885877, 0.56382184, 0.85272068])

# %%
#Создайте двумерный массив 6x6, заполненный случайными значениями. 
#Затем сумму по каждой строке поделите на минимальный элемент из столбца с тем же индексом.
a=np.random.random((6,6))
b=a.min(axis=0)
[sum(a[i,:])/b[i] for i in range(6)]

# %%
#На примере массива x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) 
#найдите максимальный элемент в массиве среди элементов, перед которыми стоит ноль.
x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0])         
max([x[i+1] for i in range(len(x)-1) if x[i]==0 and x[i+1]!=0])

# %%
#Пусть заданы два массива x = np.ones(10) и i = np.array([0, 1, 2, 3, 5, 5, 5, 8]).
#Прибавьте единицу к тем элементам массива x, индексы которых указаны в массиве i.
#В случае, если некоторый индекс встретился в массиве i несколько раз,
#прибавьте к соответствующему элементу массива x число вхождений данного индекса в массив i.

x=np.ones(10)
i=np.array([0,1,2,3,5,5,5,8])

a,b=np.unique(i,return_counts=True)
print(a,b,sep='   ')
x[a]+=b
print(x)
#Без циклов!!!

# %%
#По заданному двумерному массиву размера NxN постройте словарь, 
#ключи которого - индексы диагоналей, параллельных побочной (нумерация начинается с 0),
#а значения - списки элементов исходного массива, лежащих на соответствующих диагоналях.
#Решите задачу на примере массива a = np.arange(16).reshape(4, 4), 
#в результате должен получиться словарь
#{0: [0], 1: [1, 4], 2: [2, 5, 8], 3: [3, 6, 9, 12], 4: [7, 10, 13], 5: [11, 14], 6: [15]}.
a=np.arange(16).reshape(4, 4)
di = dict()
for i in range(4):
    b=[a[0+j][i-j] for j in range(i+1)]
    di[i]=b
for i in range(4,7):
    b=[a[i-3+j][3-j] for j in range(7-i)]
    di[i]=b
print(di)

# %%
#Написать функцию, реализующую алгоритм k-means
import matplotlib.pyplot as plt
#Скачаем Dataset
fname='Dataset_eruption.txt'
data = np.loadtxt(fname, skiprows=26)[:, 1:]
#Построим график
plt.scatter(*data.T)
plt.xlabel('Eruption time (min)')
plt.ylabel('Waiting time ti next eruption (min)')
plt.show()
#Вычтем среднее и сделаем единичную дисперсию
data=(data-[np.mean(data[:,0]),np.mean(data[:,1])])/[np.std(data[:,0]),np.std(data[:,1])]

plt.scatter(*data.T)
plt.show()
#Создадим центры
centroids = np.random.uniform(-2, 2, 4).reshape((2, 2))

def get_labels(pts, centroids):
    y=True
    while y:
        #Посчитаем расстояния до центров
       
        dist0 = np.linalg.norm(pts-centroids[0,:],axis=1)
        dist1 = np.linalg.norm(pts-centroids[1,:],axis=1)
        #Построим матрицу, где по столбцам записаны расстояния до пронумерованных центров
        dist=np.vstack((dist0, dist1)).T
        #Получим метки для каждой точки
        labels=np.argmin(dist,axis=1)
        #Пересчитаем центры
        Klaster0=pts[labels==0,:]
        Klaster1=pts[labels==1,:]
        offset=np.array([np.mean(Klaster0,axis=0),np.mean(Klaster1,axis=0)])
        if (offset==centroids).all():
            y=False
        else:
            centroids=offset.copy()
    return labels

labels = get_labels(data, centroids)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(*data.T, c=np.where(labels, "green", "red"), s=20)
plt.scatter(*centroids.T, c=["red", "green"], s=95, marker='*')
plt.title('Predicted Classes')
plt.show()
